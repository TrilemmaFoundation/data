# %% [markdown]
# # NOAA GML Mauna Loa CO2
#
# Monthly atmospheric carbon dioxide measurements from Mauna Loa for building climate-trend monitors and educational concentration trackers.
#
# - Guide: https://data.trilemma.foundation/datasets/noaa-gml-co2
# - Official source: https://gml.noaa.gov/ccgg/trends/data.html
# - Data terms: https://www.noaa.gov/disclaimer
# - Last verified: 2026-08-18

# %% [markdown]
# ## Overview
#
# NOAA GML publishes monthly mean carbon dioxide mole fractions from the Mauna Loa observatory as a small CSV. Start with the in-situ monthly file. These values represent one high-altitude Pacific site after quality control, not a global average or a local urban concentration.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the data
#
# 1. Open the Trends in CO2 data page and identify the Mauna Loa monthly mean CSV.
# 2. Load the file, skipping comment rows that begin with a hash.
# 3. Keep year, month, and the seasonally adjusted monthly mean.

# %% [markdown]
# ## Install packages
#
# Run this cell first.

# %%
# python -m pip install pandas
python -m pip install pandas

# %% [markdown]
# ## Python example

# %%
import pandas as pd

co2 = pd.read_csv(
    "https://gml.noaa.gov/webdata/ccgg/trends/co2/co2_mm_mlo.csv",
    comment="#",
)
co2["date"] = pd.to_datetime(
    dict(year=co2["year"], month=co2["month"], day=1)
)
print(co2[["date", "average", "deseasonalized"]].tail())

# %% [markdown]
# ## First project: Chart Mauna Loa monthly CO2
#
# Test whether the monthly file can power a simple concentration-trend monitor.
#
# 1. Drop rows where the monthly average is a missing-value sentinel.
# 2. Plot the monthly average and the deseasonalized series over the full record.
# 3. Explain that Mauna Loa is one background site and is not a global or city-level CO2 product.
