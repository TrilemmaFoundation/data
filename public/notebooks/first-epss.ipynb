# %% [markdown]
# # FIRST Exploit Prediction Scoring System
#
# Daily CVE exploit-probability scores for building patch-priority queues that go beyond severity ratings and known-exploited lists.
#
# - Guide: https://data.trilemma.foundation/datasets/first-epss
# - Official source: https://www.first.org/epss/
# - Data terms: https://www.first.org/epss/faq
# - Last verified: 2026-08-18

# %% [markdown]
# ## Overview
#
# EPSS estimates the probability that a published CVE will be exploited in the next 30 days. Start with one CVE and the current daily score. EPSS is a likelihood model, not proof of exploitation, and it does not replace asset exposure or CISA Known Exploited Vulnerabilities evidence.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the Data
#
# 1. Read the EPSS FAQ, including the request to attribute FIRST when scores appear in a product.
# 2. Request the current score for one CVE from the public API.
# 3. Keep the CVE identifier, EPSS score, percentile, and retrieval time.

# %% [markdown]
# ## Install Packages
#
# Run this cell first.

# %%
# %pip install pandas requests
# %pip install pandas requests

# %% [markdown]
# ## Python Example

# %%
import pandas as pd
import requests

response = requests.get(
    "https://api.first.org/data/v1/epss",
    params={"cve": "CVE-2024-3400"},
    timeout=30,
)
response.raise_for_status()
scores = pd.DataFrame(response.json()["data"])
scores["retrieved_at_utc"] = pd.Timestamp.now(tz="UTC")
print(scores[["cve", "epss", "percentile", "date"]].head())

# %% [markdown]
# ## First Project: Compare One CVE's Exploit Probability with Its KEV Status
#
# Test whether EPSS can rank a published CVE before treating it as an active incident.
#
# 1. Retrieve the current EPSS score and percentile for CVE-2024-3400.
# 2. Record whether the same CVE appears on an authorized Known Exploited Vulnerabilities list.
# 3. Explain why a high EPSS score is not the same as confirmed exploitation or organizational exposure.
