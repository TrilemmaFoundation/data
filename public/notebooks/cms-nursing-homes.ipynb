# %% [markdown]
# # CMS Nursing Home Compare
#
# Medicare-certified nursing home ratings, staffing, and inspection records for building local long-term-care comparison tools.
#
# - Guide: https://data.trilemma.foundation/datasets/cms-nursing-homes
# - Official source: https://data.cms.gov/provider-data/api/1/metastore/schemas/dataset/items/4pq5-n9py
# - Data terms: https://www.cms.gov/data-research/cms-data/cms-data-principles-and-operating-norms
# - Last verified: 2026-08-18

# %% [markdown]
# ## Overview
#
# Nursing Home Provider Information lists certified facilities with Five-Star ratings, staffing, and inspection dates. Start with one state and the stable dataset identifier. Ratings can be missing, inspections lag events, and a star rating is not a clinical recommendation.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the Data
#
# 1. Open the Provider Information dataset and read the data dictionary.
# 2. Query the stable dataset identifier for a bounded page of facilities.
# 3. Preserve CMS Certification Number values as text.

# %% [markdown]
# ## Install Packages
#
# Run this cell first.

# %%
# python -m pip install pandas requests
python -m pip install pandas requests

# %% [markdown]
# ## Python Example

# %%
import pandas as pd
import requests

response = requests.get(
    "https://data.cms.gov/provider-data/api/1/datastore/query/4pq5-n9py/0",
    params={
        "limit": 20,
        "conditions[0][property]": "state",
        "conditions[0][value]": "CA",
        "conditions[0][operator]": "=",
    },
    timeout=30,
)
response.raise_for_status()
homes = pd.DataFrame(response.json()["results"])
print(
    homes[
        [
            "cms_certification_number_ccn",
            "provider_name",
            "state",
            "overall_rating",
        ]
    ].head(20)
)

# %% [markdown]
# ## First Project: Compare Nursing Homes within One State
#
# Summarize Five-Star ratings and staffing for facilities in one state.
#
# 1. Filter records by state while preserving CMS Certification Numbers as text.
# 2. Summarize overall ratings and report missingness before ranking facilities.
# 3. Explain why inspection lag, missing ratings, and resident mix limit a quality comparison.
