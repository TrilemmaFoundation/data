# %% [markdown]
# # MEDSL County Presidential Returns
#
# County-level U.S. presidential election returns for building result maps and turnout comparison tools from MIT Election Data and Science Lab files.
#
# - Guide: https://data.trilemma.foundation/datasets/medsl-county-returns
# - Official source: https://electionlab.mit.edu/data
# - Data terms: https://creativecommons.org/publicdomain/zero/1.0/
# - Last verified: 2026-08-18

# %% [markdown]
# ## Overview
#
# MEDSL publishes county presidential returns on Harvard Dataverse. Start with one election year and two-party totals. County shapefiles, third-party votes, and certified state files can disagree, and this is not precinct data.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the Data
#
# 1. Open the MEDSL data page and follow the county presidential returns Dataverse record.
# 2. Download the CSV for the latest presidential cycle.
# 3. Keep year, county FIPS, Democratic votes, and Republican votes.

# %% [markdown]
# ## Install Packages
#
# Run this cell first.

# %%
# %pip install pandas
# %pip install pandas

# %% [markdown]
# ## Python Example

# %%
import pandas as pd

returns = pd.read_csv(
    "https://dataverse.harvard.edu/api/access/datafile/6188156",
    encoding="latin-1",
)
print(returns.head())

# %% [markdown]
# ## First Project: Map One Year's County Presidential Margins
#
# Test whether county returns can power a bounded result-map prototype.
#
# 1. Filter to one year and keep county FIPS plus Democratic and Republican votes.
# 2. Compute two-party vote share and list counties with missing FIPS.
# 3. Explain that county totals can differ from certified state files and are not precinct results.
