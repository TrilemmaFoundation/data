# %% [markdown]
# # CDC FluView ILINet
#
# Weekly U.S. outpatient influenza-like illness activity for building seasonal respiratory-illness monitoring tools.
#
# - Guide: https://data.trilemma.foundation/datasets/cdc-fluview-ilinet
# - Official source: https://www.cdc.gov/fluview/overview/index.html
# - Data terms: https://www.cdc.gov/other/agencymaterials.html
# - Last verified: 2026-08-18

# %% [markdown]
# ## Overview
#
# FluView publishes ILINet outpatient respiratory-illness activity on data.cdc.gov. Start with a few recent weeks. ILI is syndromic — fever plus cough or sore throat — not laboratory-confirmed influenza incidence.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the data
#
# 1. Read the FluView methods page and note that ILINet is outpatient syndromic surveillance.
# 2. Request a bounded JSON extract from the Outpatient Respiratory Illness Activity Map dataset.
# 3. Keep geography, week, and activity level with the retrieval timestamp.

# %% [markdown]
# ## Install packages
#
# Run this cell first.

# %%
# python -m pip install pandas requests
python -m pip install pandas requests

# %% [markdown]
# ## Python example

# %%
import pandas as pd
import requests

response = requests.get(
    "https://data.cdc.gov/resource/6svj-q4zv.json",
    params={"$limit": 20, "$order": "week_ending DESC"},
    timeout=30,
)
response.raise_for_status()
ili = pd.DataFrame(response.json())
ili["retrieved_at_utc"] = pd.Timestamp.now(tz="UTC")
print(ili.head(20))

# %% [markdown]
# ## First project: Compare recent state ILI activity levels
#
# Test whether weekly activity categories can power a bounded flu-season dashboard.
#
# 1. Inspect the returned geography and week fields and keep the latest week.
# 2. Count states by activity level and note missing jurisdictions.
# 3. Explain that ILINet captures any matching respiratory illness and is not confirmed flu incidence.
