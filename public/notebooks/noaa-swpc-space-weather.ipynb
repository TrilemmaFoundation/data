# %% [markdown]
# # NOAA SWPC Space Weather
#
# Operational geomagnetic and space-weather indices for building grid, radio, and satellite-environment monitors.
#
# - Guide: https://data.trilemma.foundation/datasets/noaa-swpc-space-weather
# - Official source: https://www.spaceweather.gov/content/data-access
# - Data terms: https://www.noaa.gov/disclaimer
# - Last verified: 2026-08-18

# %% [markdown]
# ## Overview
#
# SWPC publishes JSON products for planetary K-index and related scales. Start with the compact planetary K-index file. A high Kp value is not a confirmed power-grid outage, radio blackout, or satellite anomaly.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the Data
#
# 1. Open the SWPC data-access page and note the JSON product directory.
# 2. Download the planetary K-index JSON feed.
# 3. Record observed versus estimated values and the retrieval timestamp.

# %% [markdown]
# ## Install Packages
#
# Run this cell first.

# %%
# %pip install pandas requests
# %pip install pandas requests

# %% [markdown]
# ## Python Example

# %%
import pandas as pd
import requests

response = requests.get(
    "https://services.swpc.noaa.gov/products/noaa-planetary-k-index.json",
    timeout=30,
)
response.raise_for_status()
kp = pd.DataFrame(response.json())
kp["retrieved_at_utc"] = pd.Timestamp.now(tz="UTC")
print(kp.tail(12))

# %% [markdown]
# ## First Project: Flag Elevated Planetary K-Index Periods
#
# Test whether recent Kp values can trigger a bounded space-weather awareness alert.
#
# 1. Convert time_tag to timestamps and kp to numbers.
# 2. List periods at or above Kp 5 and separate observed from estimated rows.
# 3. Explain that Kp is not a grid-outage confirmation and that NOAA scales describe potential impacts only.
