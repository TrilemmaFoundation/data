# %% [markdown]
# # NSF Awards API
#
# National Science Foundation award records for building research-funding monitors and institution comparison tools.
#
# - Guide: https://data.trilemma.foundation/datasets/nsf-awards
# - Official source: https://resources.research.gov/common/webapi/awardapisearch-v1.htm
# - Data terms: https://www.usa.gov/government-copyright
# - Last verified: 2026-08-18

# %% [markdown]
# ## Overview
#
# The NSF Awards API searches Research.gov award records by keyword. Start with one term and a 25-record page. Award amounts can span multiple years, and NSF is not a complete picture of U.S. research funding.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the Data
#
# 1. Open the Awards API documentation and note the 25-result page limit.
# 2. Search one keyword with JSON output.
# 3. Keep award id, title, institution, and amount.

# %% [markdown]
# ## Install Packages
#
# Run this cell first.

# %%
# %pip install pandas requests
# %pip install pandas requests

# %% [markdown]
# ## Python Example

# %%
import pandas as pd
import requests

response = requests.get(
    "https://api.nsf.gov/services/v1/awards.json",
    params={"keyword": "quantum", "rpp": 25},
    timeout=30,
)
response.raise_for_status()
awards = pd.json_normalize(response.json()["response"]["award"])
awards["retrieved_at_utc"] = pd.Timestamp.now(tz="UTC")
print(awards[["id", "title", "awardeeName", "estimatedTotalAmt"]].head())

# %% [markdown]
# ## First Project: List Recent NSF Quantum Awards
#
# Test whether a keyword search can power a bounded funding inbox.
#
# 1. Keep award id, title, awardee, and estimated total amount from the first page.
# 2. Sum amounts by institution and flag missing amounts.
# 3. Explain that page size is capped and that NSF awards are not all U.S. research funding.
