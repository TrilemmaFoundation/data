# %% [markdown]
# # NCHS Provisional Mortality
#
# Weekly provisional U.S. death counts by jurisdiction for building mortality monitors and excess-death research prototypes.
#
# - Guide: https://data.trilemma.foundation/datasets/nchs-provisional-mortality
# - Official source: https://data.cdc.gov/NCHS/Weekly-Provisional-Counts-of-Deaths-by-State-and-/muzy-jte6
# - Data terms: https://www.cdc.gov/other/agencymaterials.html
# - Last verified: 2026-08-18

# %% [markdown]
# ## Overview
#
# NCHS publishes weekly provisional death counts on data.cdc.gov. Start with one jurisdiction and all-cause deaths. Provisional counts are incomplete, lag varies by state, and they are not cause-specific research files from WONDER.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the Data
#
# 1. Open the Weekly Provisional Counts dataset page.
# 2. Query one jurisdiction through the Socrata JSON endpoint.
# 3. Keep week-ending date, jurisdiction, and all-cause deaths.

# %% [markdown]
# ## Install Packages
#
# Run this cell first.

# %%
# %pip install pandas requests
# %pip install pandas requests

# %% [markdown]
# ## Python Example

# %%
import pandas as pd
import requests

response = requests.get(
    "https://data.cdc.gov/resource/muzy-jte6.json",
    params={
        "$where": "jurisdiction_of_occurrence='California'",
        "$limit": 52,
        "$order": "week_ending_date DESC",
    },
    timeout=30,
)
response.raise_for_status()
deaths = pd.DataFrame(response.json())
deaths["retrieved_at_utc"] = pd.Timestamp.now(tz="UTC")
print(deaths.head())

# %% [markdown]
# ## First Project: Chart California Weekly Deaths
#
# Test whether provisional counts can power a bounded mortality sparkline.
#
# 1. Convert week-ending dates and all-cause counts to usable types.
# 2. Plot the latest year of weekly deaths and note weeks that may still be incomplete.
# 3. Explain that provisional NCHS counts lag and are not the final vital-statistics file.
