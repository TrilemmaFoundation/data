# %% [markdown]
# # UN Security Council Consolidated List
#
# UN Security Council sanctions designations for building bounded screening alerts that stay inside list-matching limits.
#
# - Guide: https://data.trilemma.foundation/datasets/un-sc-consolidated-list
# - Official source: https://main.un.org/securitycouncil/en/content/un-sc-consolidated-list
# - Data terms: https://www.un.org/en/about-us/terms-of-use
# - Last verified: 2026-08-18

# %% [markdown]
# ## Overview
#
# The Security Council publishes a consolidated XML list of designated individuals and entities. Start with exact primary names. A string match is not a confirmed hit, aliases matter, and this list is not OFAC or a complete global sanctions product.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the Data
#
# 1. Open the consolidated list page and locate the English XML download.
# 2. Load INDIVIDUAL and ENTITY records from the XML.
# 3. Keep DATAID, first and last names or entity name, and listed-on date.

# %% [markdown]
# ## Install Packages
#
# Run this cell first.

# %%
# %pip install pandas lxml
# %pip install pandas lxml

# %% [markdown]
# ## Python Example

# %%
import pandas as pd

xml = pd.read_xml(
    "https://scsanctions.un.org/resources/xml/en/consolidated.xml",
    xpath=".//INDIVIDUAL",
)
xml["retrieved_at_utc"] = pd.Timestamp.now(tz="UTC")
print(xml.head())

# %% [markdown]
# ## First Project: Build an Exact-Name UN List Lookup
#
# Test whether primary individual names can support a bounded screening prototype.
#
# 1. Load individuals and keep DATAID plus first and last name fields.
# 2. Compare a short authorized name list using exact uppercase matching only.
# 3. Explain that aliases, transliteration, and entity records require the rest of the XML and that a match is not a legal determination.
