# %% [markdown]
# # Vancouver Property Addresses
#
# Primary mapped addresses, parcel and site identifiers, local areas, and coordinates for building geocoding and property entity-resolution tools.
#
# - Guide: https://data.trilemma.foundation/datasets/vancouver-property-addresses
# - Official source: https://opendata.vancouver.ca/explore/dataset/property-addresses/
# - Data terms: https://opendata.vancouver.ca/pages/licence/
# - Last verified: 2026-09-03

# %% [markdown]
# ## Overview
#
# Start with one local area and a small API page of mapped addresses. The source contains primary VanMap display addresses and does not include every address, includes duplicates, and has geometry less precise than survey data.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the Data
#
# 1. Open the official dataset page and review the completeness and precision notes.
# 2. Query a bounded page through the OpenDataSoft API.
# 3. Keep civic number, street, parcel id, site id, local area, and coordinates.

# %% [markdown]
# ## Install Packages
#
# Run this cell first.

# %%
# %pip install pandas requests
# %pip install pandas requests

# %% [markdown]
# ## Python Example

# %%
import pandas as pd
import requests

url = "https://opendata.vancouver.ca/api/explore/v2.1/catalog/datasets/property-addresses/records"
response = requests.get(url, params={"limit": 100}, timeout=30)
response.raise_for_status()
addresses = pd.json_normalize(response.json()["results"])
columns = [
    "civic_number",
    "std_street",
    "p_parcel_id",
    "site_id",
    "geo_local_area",
    "geo_point_2d.lat",
    "geo_point_2d.lon",
]
print(addresses[columns].head())

# %% [markdown]
# ## First Project: Build a Property Address Crosswalk
#
# Test whether parcel and site identifiers can connect address-based Vancouver datasets.
#
# 1. Construct a normalized civic-number and street key.
# 2. Measure duplicate address keys and missing parcel or site identifiers.
# 3. Explain why primary-address coverage, duplicates, and coordinate precision limit geocoding completeness.
