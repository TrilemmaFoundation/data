# %% [markdown]
# # Vancouver Parking Tickets
#
# Parking infractions, dates, statuses, bylaws, and 100-block locations for building enforcement hotspot and curb-demand analysis tools.
#
# - Guide: https://data.trilemma.foundation/datasets/vancouver-parking-tickets
# - Official source: https://opendata.vancouver.ca/explore/dataset/parking-tickets/
# - Data terms: https://opendata.vancouver.ca/pages/licence/
# - Last verified: 2026-09-03

# %% [markdown]
# ## Overview
#
# Start with one year and a small API page of infractions. Locations are aggregated to 100-block units, Vancouver Police Department tickets are excluded, and records do not show later status changes.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the Data
#
# 1. Open the official dataset page and review the location and coverage notes.
# 2. Query a bounded page through the OpenDataSoft API.
# 3. Keep infraction date, block, street, bylaw, section, status, and description.

# %% [markdown]
# ## Install Packages
#
# Run this cell first.

# %%
# python -m pip install pandas requests
python -m pip install pandas requests

# %% [markdown]
# ## Python Example

# %%
import pandas as pd
import requests

url = "https://opendata.vancouver.ca/api/explore/v2.1/catalog/datasets/parking-tickets/records"
response = requests.get(
    url,
    params={"limit": 100, "order_by": "entrydate DESC"},
    timeout=30,
)
response.raise_for_status()
tickets = pd.json_normalize(response.json()["results"])
columns = [
    "entrydate",
    "block",
    "street",
    "bylaw",
    "section",
    "status",
    "infractiontext",
]
print(tickets[columns].head())

# %% [markdown]
# ## First Project: Find Parking Enforcement Hotspots
#
# Test whether ticket counts can support a coarse block-level enforcement map.
#
# 1. Group sampled tickets by street, 100-block, and infraction description.
# 2. Compare counts across dates and ticket statuses.
# 3. Explain why block aggregation, agency exclusions, and issue-date status limit parking-demand conclusions.
