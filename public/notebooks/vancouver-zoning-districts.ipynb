# %% [markdown]
# # Vancouver Zoning Districts and Labels
#
# Zoning polygons, classifications, categories, districts, and CD-1 identifiers for building land-use and development-potential analysis tools.
#
# - Guide: https://data.trilemma.foundation/datasets/vancouver-zoning-districts
# - Official source: https://opendata.vancouver.ca/explore/dataset/zoning-districts-and-labels/
# - Data terms: https://opendata.vancouver.ca/pages/licence/
# - Last verified: 2026-09-03

# %% [markdown]
# ## Overview
#
# Start with one zoning classification and a small page of district polygons. Some features are less precise than survey data, and the dataset does not replace the Zoning and Development By-law.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the Data
#
# 1. Open the official dataset page and review the accuracy and by-law notes.
# 2. Query a bounded page through the OpenDataSoft API.
# 3. Keep object id, classification, category, district, CD-1 number, and geometry.

# %% [markdown]
# ## Install Packages
#
# Run this cell first.

# %%
# python -m pip install pandas requests
python -m pip install pandas requests

# %% [markdown]
# ## Python Example

# %%
import pandas as pd
import requests

url = "https://opendata.vancouver.ca/api/explore/v2.1/catalog/datasets/zoning-districts-and-labels/records"
response = requests.get(url, params={"limit": 100}, timeout=30)
response.raise_for_status()
zoning = pd.DataFrame(response.json()["results"])
columns = [
    "object_id",
    "zoning_classification",
    "zoning_category",
    "zoning_district",
    "cd_1_number",
]
print(zoning[columns].head())
print(zoning["geom"].iloc[0]["geometry"]["type"])

# %% [markdown]
# ## First Project: Summarize Zoning by Classification
#
# Test whether district polygons can support a neighbourhood land-use inventory.
#
# 1. Count district features by zoning classification and category.
# 2. Identify classifications with multiple zoning districts or CD-1 identifiers.
# 3. Explain why polygon precision and the authoritative by-law limit development-potential claims.
