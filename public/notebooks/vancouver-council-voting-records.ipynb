# %% [markdown]
# # Vancouver Council Voting Records
#
# Individual councillor votes, agenda descriptions, decisions, and meeting timestamps for building voting-bloc and policy-topic analysis tools.
#
# - Guide: https://data.trilemma.foundation/datasets/vancouver-council-voting-records
# - Official source: https://opendata.vancouver.ca/explore/dataset/council-voting-records/
# - Data terms: https://opendata.vancouver.ca/pages/licence/
# - Last verified: 2026-09-03

# %% [markdown]
# ## Overview
#
# Start with one meeting date and a small API page of individual votes. Meeting minutes remain the official record, excluded vote types reduce coverage, and consent votes may be entered after a meeting.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the Data
#
# 1. Open the official dataset page and review the excluded-vote and official-record notes.
# 2. Query a bounded page through the OpenDataSoft API.
# 3. Keep vote number, date, agenda description, councillor, vote, and decision.

# %% [markdown]
# ## Install Packages
#
# Run this cell first.

# %%
# %pip install pandas requests
# %pip install pandas requests

# %% [markdown]
# ## Python Example

# %%
import pandas as pd
import requests

url = "https://opendata.vancouver.ca/api/explore/v2.1/catalog/datasets/council-voting-records/records"
response = requests.get(
    url,
    params={"limit": 100, "order_by": "vote_date DESC"},
    timeout=30,
)
response.raise_for_status()
votes = pd.json_normalize(response.json()["results"])
columns = [
    "vote_number",
    "vote_date",
    "agenda_description",
    "council_member",
    "vote",
    "decision",
]
print(votes[columns].head())

# %% [markdown]
# ## First Project: Compare Council Voting Patterns
#
# Test whether individual votes can support a bounded councillor-similarity view.
#
# 1. Pivot the sample into councillors by vote number.
# 2. Calculate agreement rates only where both councillors recorded eligible votes.
# 3. Explain why excluded motions, consent entries, and official minutes limit voting-bloc conclusions.
