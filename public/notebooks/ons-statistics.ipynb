# %% [markdown]
# # ONS Statistics API
#
# Official UK statistical datasets for building local labour, prices, and population tools from Office for National Statistics.
#
# - Guide: https://data.trilemma.foundation/datasets/ons-statistics
# - Official source: https://developer.ons.gov.uk/
# - Data terms: https://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/
# - Last verified: 2026-08-18

# %% [markdown]
# ## Overview
#
# The ONS API returns dataset metadata and observations. Start with one edition of CPIH or a labour dataset and a few observations. UK statistics have geography codes that do not match U.S. FIPS, and some tables are still Excel-only.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the Data
#
# 1. Open the ONS developer hub and pick one dataset id.
# 2. Request the latest edition metadata, then a small observation slice.
# 3. Cite ONS under the Open Government Licence.

# %% [markdown]
# ## Install Packages
#
# Run this cell first.

# %%
# %pip install pandas requests
# %pip install pandas requests

# %% [markdown]
# ## Python Example

# %%
import pandas as pd
import requests

response = requests.get(
    "https://api.beta.ons.gov.uk/v1/datasets/cpih01/editions/time-series/versions/1/observations",
    params={"time": "latest", "geography": "K02000001"},
    timeout=30,
)
response.raise_for_status()
observations = pd.json_normalize(response.json().get("observations", []))
observations["retrieved_at_utc"] = pd.Timestamp.now(tz="UTC")
print(observations.head())

# %% [markdown]
# ## First Project: Read a UK CPIH Observation
#
# Test whether the ONS API can power a bounded UK prices card.
#
# 1. Confirm an observation value returned for the selected dataset and geography.
# 2. Record the edition version and observation time used.
# 3. Cite ONS under OGL and explain that UK geography codes are not U.S. FIPS and that editions are versioned.
