# %% [markdown]
# # OurAirports
#
# Community airport, runway, and navaid records for building aviation directories and map layers from a nightly public-domain CSV.
#
# - Guide: https://data.trilemma.foundation/datasets/ourairports
# - Official source: https://ourairports.com/data/
# - Data terms: https://ourairports.com/data/
# - Last verified: 2026-08-18

# %% [markdown]
# ## Overview
#
# OurAirports publishes a nightly airports.csv covering worldwide aerodromes. Start with large airports in one country. Community coordinates and names can be incomplete, and the file is not an official aeronautical chart.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the Data
#
# 1. Open the data page and note the public-domain terms.
# 2. Download airports.csv from the published GitHub Pages mirror.
# 3. Filter to one ISO country and large airports before mapping.

# %% [markdown]
# ## Install Packages
#
# Run this cell first.

# %%
# python -m pip install pandas
python -m pip install pandas

# %% [markdown]
# ## Python Example

# %%
import pandas as pd

airports = pd.read_csv(
    "https://davidmegginson.github.io/ourairports-data/airports.csv"
)
us_large = airports[
    (airports["iso_country"] == "US")
    & (airports["type"] == "large_airport")
]
print(
    us_large[
        ["ident", "name", "municipality", "latitude_deg", "longitude_deg"]
    ].head()
)

# %% [markdown]
# ## First Project: Map Large U.S. Airports from the Public-Domain Dump
#
# Test whether OurAirports can power a bounded aviation directory layer.
#
# 1. Keep ident, name, municipality, and coordinates for U.S. large airports.
# 2. Count missing municipalities before plotting.
# 3. Explain that community airport records are not a substitute for official NASR or AIP charts.
