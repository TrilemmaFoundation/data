# %% [markdown]
# # Vancouver Property Tax Report
#
# Property assessments, tax levies, zoning, and building details for building parcel-level housing and redevelopment analysis tools.
#
# - Guide: https://data.trilemma.foundation/datasets/vancouver-property-tax-report
# - Official source: https://opendata.vancouver.ca/explore/dataset/property-tax-report/
# - Data terms: https://opendata.vancouver.ca/pages/licence/
# - Last verified: 2026-09-03

# %% [markdown]
# ## Overview
#
# Start with one assessment year and a small API page of parcels. Historical files omit some zoning and previous-value fields, and assessment values are not the same as taxable values.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the Data
#
# 1. Open the official dataset page and review the notes for the selected assessment year.
# 2. Query a bounded page through the OpenDataSoft API.
# 3. Keep the report year, parcel identifier, values, levy, and zoning fields.

# %% [markdown]
# ## Install Packages
#
# Run this cell first.

# %%
# %pip install pandas requests
# %pip install pandas requests

# %% [markdown]
# ## Python Example

# %%
import pandas as pd
import requests

url = "https://opendata.vancouver.ca/api/explore/v2.1/catalog/datasets/property-tax-report/records"
response = requests.get(url, params={"limit": 100}, timeout=30)
response.raise_for_status()
properties = pd.json_normalize(response.json()["results"])
columns = [
    "pid",
    "tax_assessment_year",
    "current_land_value",
    "current_improvement_value",
    "tax_levy",
    "zoning_district",
]
print(properties[columns].head())

# %% [markdown]
# ## First Project: Compare Land and Improvement Values
#
# Test whether one assessment year can support a parcel-level redevelopment signal.
#
# 1. Filter the sample to records with parcel identifiers and both current value fields.
# 2. Calculate land value as a share of total assessed value.
# 3. Explain why assessment timing, missing historical fields, and taxable-value rules limit comparisons.
