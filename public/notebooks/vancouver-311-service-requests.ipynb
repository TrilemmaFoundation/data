# %% [markdown]
# # Vancouver 3-1-1 Service Requests
#
# Resident service requests, locations, departments, statuses, and closure details for building neighbourhood issue and response-time monitors.
#
# - Guide: https://data.trilemma.foundation/datasets/vancouver-311-service-requests
# - Official source: https://opendata.vancouver.ca/explore/dataset/3-1-1-service-requests/
# - Data terms: https://opendata.vancouver.ca/pages/licence/
# - Last verified: 2026-09-03

# %% [markdown]
# ## Overview
#
# Start with one service-request type and a small recent API page. Some addresses are suppressed for privacy, some records cannot be geocoded, and the case-management system changed in August 2022.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the Data
#
# 1. Open the official dataset page and review the privacy and system-change notes.
# 2. Query a bounded page through the OpenDataSoft API.
# 3. Keep request type, department, timestamps, status, local area, and coordinates.

# %% [markdown]
# ## Install Packages
#
# Run this cell first.

# %%
# python -m pip install pandas requests
python -m pip install pandas requests

# %% [markdown]
# ## Python Example

# %%
import pandas as pd
import requests

url = "https://opendata.vancouver.ca/api/explore/v2.1/catalog/datasets/3-1-1-service-requests/records"
response = requests.get(
    url,
    params={"limit": 100, "order_by": "service_request_open_timestamp DESC"},
    timeout=30,
)
response.raise_for_status()
requests_311 = pd.json_normalize(response.json()["results"])
columns = [
    "service_request_type",
    "department",
    "status",
    "service_request_open_timestamp",
    "service_request_close_date",
    "local_area",
    "latitude",
    "longitude",
]
print(requests_311[columns].head())

# %% [markdown]
# ## First Project: Map Recent 3-1-1 Requests
#
# Test whether recent request counts can support a neighbourhood issue monitor.
#
# 1. Group the sample by service-request type and local area.
# 2. Calculate closure durations where both timestamps are available.
# 3. Explain how privacy suppression, missing coordinates, and the 2022 system change limit comparisons.
