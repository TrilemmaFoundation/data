# %% [markdown]
# # Open Food Facts
#
# Collaborative packaged-food product records for building barcode lookup, label, and nutrition-comparison tools.
#
# - Guide: https://data.trilemma.foundation/datasets/open-food-facts
# - Official source: https://world.openfoodfacts.org/
# - Data terms: https://world.openfoodfacts.org/terms-of-use
# - Last verified: 2026-08-18

# %% [markdown]
# ## Overview
#
# Open Food Facts publishes packaged-product facts, including Nutri-Score and ingredient lists, under ODbL. Start with one barcode and a custom User-Agent. Contributor data can be incomplete, images have a separate share-alike licence, and the database is not medical advice.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the Data
#
# 1. Read the terms of use, including attribution and share-alike for derivative databases.
# 2. Request one product by barcode with a descriptive User-Agent.
# 3. Keep the barcode, product name, and Nutri-Score if present.

# %% [markdown]
# ## Install Packages
#
# Run this cell first.

# %%
# python -m pip install pandas requests
python -m pip install pandas requests

# %% [markdown]
# ## Python Example

# %%
import pandas as pd
import requests

response = requests.get(
    "https://world.openfoodfacts.org/api/v2/product/737628064502.json",
    headers={
        "User-Agent": (
            "TrilemmaDataCatalogExample/1.0 "
            "(https://data.trilemma.foundation)"
        )
    },
    timeout=30,
)
response.raise_for_status()
product = pd.json_normalize(response.json()["product"])
print(product.filter(regex="code|product_name|nutriscore|brands").head())

# %% [markdown]
# ## First Project: Look Up One Packaged Food by Barcode
#
# Test whether Open Food Facts can power a bounded product-fact card.
#
# 1. Keep barcode, product name, brands, and Nutri-Score.
# 2. Record missing nutrition or ingredient fields instead of filling them from other sites.
# 3. Attribute Open Food Facts under ODbL and note that images and third-party packaging rights are separate.
