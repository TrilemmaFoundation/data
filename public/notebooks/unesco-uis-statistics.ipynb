# %% [markdown]
# # UNESCO UIS Statistics API
#
# Cross-national education indicators from the UNESCO Institute for Statistics for building country comparison and SDG 4 monitoring tools.
#
# - Guide: https://data.trilemma.foundation/datasets/unesco-uis-statistics
# - Official source: https://databrowser.uis.unesco.org/resources
# - Data terms: https://www.unesco.org/en/open-access/cc-sa
# - Last verified: 2026-08-20

# %% [markdown]
# ## Overview
#
# The UIS Data API returns internationally comparable education indicators. Start with completion rate CR.1 for one country and a few recent years. Values can lag, national definitions differ, and ShareAlike applies to adapted data products.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the Data
#
# 1. Read the UIS Data Browser resources page and confirm the indicator definition for CR.1.
# 2. Request one indicator for one country and a bounded year window.
# 3. Keep indicatorId, geoUnit, year, and value with any qualifier fields.

# %% [markdown]
# ## Install Packages
#
# Run this cell first.

# %%
# python -m pip install pandas requests
python -m pip install pandas requests

# %% [markdown]
# ## Python Example

# %%
import pandas as pd
import requests

response = requests.get(
    "https://api.uis.unesco.org/api/public/data/indicators",
    params={
        "indicator": "CR.1",
        "geoUnit": "USA",
        "start": 2020,
        "end": 2022,
    },
    timeout=30,
)
response.raise_for_status()
observations = pd.DataFrame(response.json()["records"])
observations["retrieved_at_utc"] = pd.Timestamp.now(tz="UTC")
print(observations[["indicatorId", "geoUnit", "year", "value"]].head())

# %% [markdown]
# ## First Project: Compare Primary Completion for Two Countries
#
# Test whether one UIS completion-rate series can power a bounded country comparison.
#
# 1. Repeat the request for a second country and concatenate the year-value rows.
# 2. Plot both series and report missing years before interpreting a gap.
# 3. Attribute UIS under CC BY-SA 3.0 IGO and state that national definitions can differ.
