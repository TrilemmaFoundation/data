# %% [markdown]
# # UNHCR Refugee Population Statistics
#
# Official refugee, asylum-seeker, displacement, statelessness, return, and resettlement statistics for building humanitarian trend and flow tools.
#
# - Guide: https://data.trilemma.foundation/datasets/unhcr-refugee-population
# - Official source: https://api.unhcr.org/population/v1/population/?year=2024&limit=1
# - Data terms: https://www.unhcr.org/what-we-do/data-and-publications/data-and-statistics/terms-use-datasets
# - Last verified: 2026-08-18

# %% [markdown]
# ## Overview
#
# UNHCR's database reports forcibly displaced and stateless populations by year, origin, and asylum location. Start with refugees for two countries across five years. End-of-year stocks are not annual flows, categories differ, and some values are estimates or supplied by other authorities.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the data
#
# 1. Read UNHCR's population-category definitions and select one measure.
# 2. Request a five-year window for a small country set using ISO codes.
# 3. Retrieve footnotes and retain the source year and country-role definitions.

# %% [markdown]
# ## Install packages
#
# Run this cell first.

# %%
# python -m pip install pandas requests
python -m pip install pandas requests

# %% [markdown]
# ## Python example

# %%
import pandas as pd
import requests

response = requests.get(
    "https://api.unhcr.org/population/v1/population/",
    params={
        "yearFrom": 2020,
        "yearTo": 2024,
        "coo": "AFG,UKR",
        "coa_all": "true",
        "cf_type": "ISO",
        "limit": 100,
    },
    timeout=30,
)
response.raise_for_status()
population = pd.DataFrame(response.json()["items"])
print(population[["year", "coo_name", "refugees", "asylum_seekers"]].head(20))

# %% [markdown]
# ## First project: Compare displacement stocks by origin
#
# Compare reported refugee and asylum-seeker stocks originating from Afghanistan and Ukraine from 2020 through 2024.
#
# 1. Retrieve the bounded years and retain origin, asylum, and population-category fields.
# 2. Aggregate only compatible categories and review the associated footnotes before charting.
# 3. Explain why stocks are not flows and how estimates, coverage, and category definitions limit comparison.
