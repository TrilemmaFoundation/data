# %% [markdown]
# # GLEIF Legal Entity Identifier Index
#
# Global legal-entity identifiers and reference data for building company lookup, ownership, and sanctions-screening tools.
#
# - Guide: https://data.trilemma.foundation/datasets/gleif-lei
# - Official source: https://www.gleif.org/en/lei-data/gleif-api/
# - Data terms: https://www.gleif.org/en/meta/lei-data-terms-of-use/
# - Last verified: 2026-08-18

# %% [markdown]
# ## Overview
#
# GLEIF publishes Legal Entity Identifiers and reference data under CC0. Start with one known LEI rather than the concatenated golden copy. LEI coverage is not universal, reference data can lag the entity's own filings, and an LEI is not a credit, sanctions, or beneficial-ownership decision.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the data
#
# 1. Read the GLEIF API page and the LEI Data Terms of Use, including the CC0 licence.
# 2. Request one LEI record from the public API.
# 3. Keep the LEI, legal name, jurisdiction, and registration status.

# %% [markdown]
# ## Install packages
#
# Run this cell first.

# %%
# python -m pip install pandas requests
python -m pip install pandas requests

# %% [markdown]
# ## Python example

# %%
import pandas as pd
import requests

response = requests.get(
    "https://api.gleif.org/api/v1/lei-records",
    params={"filter[lei]": "5493001KJTIIGC8Y1R12"},
    headers={"Accept": "application/vnd.api+json"},
    timeout=30,
)
response.raise_for_status()
records = pd.json_normalize(response.json()["data"])
print(records.filter(regex="id|legalName|jurisdiction|status").head())

# %% [markdown]
# ## First project: Look up one legal entity by LEI
#
# Test whether GLEIF can power a company-identity card from a single identifier.
#
# 1. Keep the LEI, legal name, jurisdiction, and registration status.
# 2. Record the last update time and any missing address fields.
# 3. Explain that an LEI does not by itself confirm ownership, sanctions status, or that the entity is still operating.
