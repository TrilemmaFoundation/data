# %% [markdown]
# # NHTSA Vehicle Recalls
#
# Daily vehicle, tire, child-seat, and equipment recall records for building safety lookups, fleet monitors, and owner notification tools.
#
# - Guide: https://data.trilemma.foundation/datasets/nhtsa-vehicle-recalls
# - Official source: https://www.nhtsa.gov/nhtsa-datasets-and-apis
# - Data terms: https://www.nhtsa.gov/about-nhtsa/terms-use
# - Last verified: 2026-08-11

# %% [markdown]
# ## Overview
#
# NHTSA publishes safety recalls by vehicle year, make, model, campaign, and affected component. Start with one exact year, make, and model and inspect the returned campaigns. Manufacturer naming varies, and recall records are different from consumer complaints, investigations, and general reliability evidence.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An exact model year, make, and model to query

# %% [markdown]
# ## Access the data
#
# 1. Read the recalls API documentation and confirm the vehicle naming used by NHTSA.
# 2. Request recalls for one model year, make, and model.
# 3. Preserve the campaign number and official remedy fields when presenting a result.

# %% [markdown]
# ## Install packages
#
# Run this cell first.

# %%
# python -m pip install pandas requests
python -m pip install pandas requests

# %% [markdown]
# ## Python example

# %%
import pandas as pd
import requests

response = requests.get(
    "https://api.nhtsa.gov/recalls/recallsByVehicle",
    params={"make": "Acura", "model": "RDX", "modelYear": 2012},
    timeout=30,
)
response.raise_for_status()
recalls = pd.DataFrame(response.json()["results"])
recalls["retrieved_at_utc"] = pd.Timestamp.now(tz="UTC")
print(recalls[["NHTSACampaignNumber", "Component", "ReportReceivedDate"]])

# %% [markdown]
# ## First project: Build a vehicle recall lookup
#
# Determine which safety campaigns apply to one exact vehicle configuration.
#
# 1. Query one model year, make, and model and remove duplicate campaign numbers.
# 2. Display each affected component, campaign date, consequence, and official remedy.
# 3. Explain how naming mismatches and the separation between recalls, complaints, and investigations limit the lookup.
