# %% [markdown]
# # PubChem Compounds
#
# Chemical identifiers, properties, and bioassay links for building compound lookup and structure-reference tools.
#
# - Guide: https://data.trilemma.foundation/datasets/pubchem-compounds
# - Official source: https://pubchem.ncbi.nlm.nih.gov/docs/pug-rest
# - Data terms: https://www.ncbi.nlm.nih.gov/home/about/policies/
# - Last verified: 2026-08-18

# %% [markdown]
# ## Overview
#
# PubChem PUG REST returns compound records by name or CID. Start with one chemical name. Properties can come from predicted or deposited sources, name resolution can hit multiple CIDs, and this is not a regulatory label.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the data
#
# 1. Open the PUG REST documentation and choose the compound-name path.
# 2. Request JSON properties for one name such as aspirin.
# 3. Keep CID, molecular formula, and molecular weight.

# %% [markdown]
# ## Install packages
#
# Run this cell first.

# %%
# python -m pip install pandas requests
python -m pip install pandas requests

# %% [markdown]
# ## Python example

# %%
import pandas as pd
import requests

response = requests.get(
    "https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/aspirin/property/MolecularFormula,MolecularWeight,IUPACName/JSON",
    timeout=30,
)
response.raise_for_status()
compounds = pd.DataFrame(response.json()["PropertyTable"]["Properties"])
compounds["retrieved_at_utc"] = pd.Timestamp.now(tz="UTC")
print(compounds)

# %% [markdown]
# ## First project: Look up aspirin identifiers
#
# Test whether PUG REST can power a bounded compound-reference card.
#
# 1. Confirm CID, formula, and molecular weight returned for the name query.
# 2. Compare multiple CIDs if the name resolves to more than one compound.
# 3. Explain that PubChem properties may be predicted or deposited and are not a DailyMed label.
