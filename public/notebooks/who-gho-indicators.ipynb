# %% [markdown]
# # WHO Global Health Observatory
#
# Official country health indicators for building life-expectancy, mortality, and coverage comparison tools.
#
# - Guide: https://data.trilemma.foundation/datasets/who-gho-indicators
# - Official source: https://www.who.int/data/gho/info/gho-odata-api
# - Data terms: https://data.who.int/about/data/terms-and-conditions
# - Last verified: 2026-08-18

# %% [markdown]
# ## Overview
#
# The GHO OData API returns WHO health indicators by country and year. Start with life expectancy at birth for one country. Values can lag, sex and age splits differ by indicator, and WHO forbids implying endorsement.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the Data
#
# 1. Read the GHO OData examples and the data.who.int terms, including CC BY 4.0 and no-endorsement rules.
# 2. Request one indicator filtered to one country and a recent year.
# 3. Keep indicator code, SpatialDim, TimeDim, and NumericValue.

# %% [markdown]
# ## Install Packages
#
# Run this cell first.

# %%
# %pip install pandas requests
# %pip install pandas requests

# %% [markdown]
# ## Python Example

# %%
import pandas as pd
import requests

response = requests.get(
    "https://ghoapi.azureedge.net/api/WHOSIS_000001",
    params={"$filter": "SpatialDim eq 'USA'", "$top": "20"},
    timeout=30,
)
response.raise_for_status()
observations = pd.DataFrame(response.json()["value"])
print(
    observations[
        ["IndicatorCode", "SpatialDim", "TimeDim", "Dim1", "NumericValue"]
    ].head()
)

# %% [markdown]
# ## First Project: Chart U.S. Life Expectancy at Birth from GHO
#
# Test whether one WHO indicator can power a bounded national trend card.
#
# 1. Keep year, sex dimension, and NumericValue for WHOSIS_000001 in the United States.
# 2. Plot the series and report missing years before interpreting a change.
# 3. Attribute WHO under CC BY 4.0 and state that the chart is not a WHO-endorsed product.
