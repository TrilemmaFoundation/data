# %% [markdown]
# # Vancouver Public Trees
#
# Public tree locations, species, dimensions, and planting dates for building urban forestry, biodiversity, and canopy equity maps.
#
# - Guide: https://data.trilemma.foundation/datasets/vancouver-public-trees
# - Official source: https://opendata.vancouver.ca/explore/dataset/public-trees/
# - Data terms: https://opendata.vancouver.ca/pages/licence/
# - Last verified: 2026-09-03

# %% [markdown]
# ## Overview
#
# Start with one species and a small API page of mapped trees. Private trees are excluded, records without coordinates are absent, and some attributes may be several years out of date.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the Data
#
# 1. Open the official dataset page and review the inventory and attribute-age notes.
# 2. Query a bounded page through the OpenDataSoft API.
# 3. Keep asset id, species, dimensions, planting date, and coordinates.

# %% [markdown]
# ## Install Packages
#
# Run this cell first.

# %%
# python -m pip install pandas requests
python -m pip install pandas requests

# %% [markdown]
# ## Python Example

# %%
import pandas as pd
import requests

url = "https://opendata.vancouver.ca/api/explore/v2.1/catalog/datasets/public-trees/records"
response = requests.get(url, params={"limit": 100}, timeout=30)
response.raise_for_status()
trees = pd.json_normalize(response.json()["results"])
columns = [
    "asset_id",
    "common_name",
    "genus_name",
    "species_name",
    "height_m",
    "diameter_cm",
    "date_planted",
    "geo_point_2d.lat",
    "geo_point_2d.lon",
]
print(trees[columns].head())

# %% [markdown]
# ## First Project: Map Public Tree Diversity
#
# Test whether species counts can support a local urban-forest diversity map.
#
# 1. Count sampled trees by genus and species.
# 2. Compare diameter and height distributions for the most common species.
# 3. Explain why private-tree exclusion, missing coordinates, and stale attributes limit canopy conclusions.
