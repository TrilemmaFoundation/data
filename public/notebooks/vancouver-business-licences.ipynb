# %% [markdown]
# # Vancouver Business Licences
#
# Business licence categories, statuses, dates, locations, and employment counts for building local commercial activity and churn monitors.
#
# - Guide: https://data.trilemma.foundation/datasets/vancouver-business-licences
# - Official source: https://opendata.vancouver.ca/explore/dataset/business-licences/
# - Data terms: https://opendata.vancouver.ca/pages/licence/
# - Last verified: 2026-09-03

# %% [markdown]
# ## Overview
#
# Start with one business type and a small page of current licence records. Categories changed in May 2024, home-based business addresses can be withheld, and licence records do not prove that a business is operating.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the Data
#
# 1. Open the official dataset page and review the category-change and privacy notes.
# 2. Query a bounded page through the OpenDataSoft API.
# 3. Keep the unique licence identifier, category, status, dates, local area, and employee count.

# %% [markdown]
# ## Install Packages
#
# Run this cell first.

# %%
# %pip install pandas requests
# %pip install pandas requests

# %% [markdown]
# ## Python Example

# %%
import pandas as pd
import requests

url = "https://opendata.vancouver.ca/api/explore/v2.1/catalog/datasets/business-licences/records"
response = requests.get(
    url,
    params={"limit": 100, "order_by": "issueddate DESC"},
    timeout=30,
)
response.raise_for_status()
licences = pd.json_normalize(response.json()["results"])
columns = [
    "licencersn",
    "businesstype",
    "businesssubtype",
    "status",
    "issueddate",
    "localarea",
    "numberofemployees",
]
print(licences[columns].head())

# %% [markdown]
# ## First Project: Track Business Licence Activity
#
# Test whether current licence records can support a neighbourhood commercial activity monitor.
#
# 1. Count issued records by business type and local area.
# 2. Compare issue dates and reported employee counts for the largest groups.
# 3. Explain why category changes, withheld addresses, and licence status limit conclusions about openings and closures.
