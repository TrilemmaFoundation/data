# %% [markdown]
# # IDMC Internal Displacement
#
# Country-year internal displacement figures for building humanitarian comparison tools alongside refugee statistics.
#
# - Guide: https://data.trilemma.foundation/datasets/idmc-internal-displacement
# - Official source: https://www.internal-displacement.org/database/displacement-data
# - Data terms: https://creativecommons.org/licenses/by/3.0/igo/
# - Last verified: 2026-08-18

# %% [markdown]
# ## Overview
#
# IDMC's Global Internal Displacement Database publishes country-year stocks and new displacements from conflict and disasters. Start with the Excel download. Figures are expert-validated estimates, not household surveys, and they are not UNHCR refugee counts.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the Data
#
# 1. Open the IDMC displacement-data page and download the GIDD Excel file.
# 2. Load the conflict-and-disasters sheet.
# 3. Keep ISO3, year, conflict displacements, and disaster displacements.

# %% [markdown]
# ## Install Packages
#
# Run this cell first.

# %%
# python -m pip install pandas requests openpyxl
python -m pip install pandas requests openpyxl

# %% [markdown]
# ## Python Example

# %%
import pandas as pd
import requests
from io import BytesIO

response = requests.get(
    "https://www.internal-displacement.org/sites/default/files/2024-05/IDMC_Internal_Displacement_Conflict-Violence_Disasters.xlsx",
    timeout=60,
)
response.raise_for_status()
displacement = pd.read_excel(BytesIO(response.content), sheet_name=0)
print(displacement.head())

# %% [markdown]
# ## First Project: Compare Conflict and Disaster Displacements
#
# Test whether GIDD country-year rows can power a bounded humanitarian sketch.
#
# 1. Keep country, year, and conflict versus disaster displacement columns.
# 2. Rank one year by new displacements and list missing ISO3 codes.
# 3. Explain that GIDD figures are curated estimates, not UNHCR refugee statistics, and can be revised.
