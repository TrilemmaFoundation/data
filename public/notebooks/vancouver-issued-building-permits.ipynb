# %% [markdown]
# # Vancouver Issued Building Permits
#
# Issued permits, project values, work types, uses, descriptions, and processing times for building construction pipeline and development hotspot tools.
#
# - Guide: https://data.trilemma.foundation/datasets/vancouver-issued-building-permits
# - Official source: https://opendata.vancouver.ca/explore/dataset/issued-building-permits/
# - Data terms: https://opendata.vancouver.ca/pages/licence/
# - Last verified: 2026-09-03

# %% [markdown]
# ## Overview
#
# Start with one permit category and a small recent API page. The records describe permits when first issued, not their current status or later changes, and some addresses cannot be geocoded.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the Data
#
# 1. Open the official dataset page and review the issuance and geocoding notes.
# 2. Query a bounded page through the OpenDataSoft API.
# 3. Keep permit number, issue date, value, elapsed days, permit category, work type, use, and local area.

# %% [markdown]
# ## Install Packages
#
# Run this cell first.

# %%
# %pip install pandas requests
# %pip install pandas requests

# %% [markdown]
# ## Python Example

# %%
import pandas as pd
import requests

url = "https://opendata.vancouver.ca/api/explore/v2.1/catalog/datasets/issued-building-permits/records"
response = requests.get(
    url,
    params={"limit": 100, "order_by": "issuedate DESC"},
    timeout=30,
)
response.raise_for_status()
permits = pd.json_normalize(response.json()["results"])
columns = [
    "permitnumber",
    "issuedate",
    "projectvalue",
    "permitelapseddays",
    "permitcategory",
    "typeofwork",
    "propertyuse",
    "geolocalarea",
]
print(permits[columns].head())

# %% [markdown]
# ## First Project: Compare Building Permit Timelines
#
# Test whether issued permits can support a neighbourhood construction pipeline monitor.
#
# 1. Group the sample by permit category and local area.
# 2. Compare median project value and elapsed days across groups.
# 3. Explain why issued-only records, applicant response time, and missing coordinates limit performance conclusions.
