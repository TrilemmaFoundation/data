# %% [markdown]
# # Wikimedia Pageviews
#
# Per-article and project pageview counts for building attention monitors and topic-trend tools.
#
# - Guide: https://data.trilemma.foundation/datasets/wikimedia-pageviews
# - Official source: https://doc.wikimedia.org/generated-data-platform/aqs/analytics-api/reference/page-views.html
# - Data terms: https://doc.wikimedia.org/generated-data-platform/aqs/analytics-api/documentation/access-policy.html
# - Last verified: 2026-08-18

# %% [markdown]
# ## Overview
#
# The Wikimedia Analytics API reports pageviews for Wikimedia projects. Start with one English Wikipedia article and a short daily window. Send a descriptive User-Agent with contact information; generic python-requests clients may be blocked. Pageviews are not a measure of quality or demand.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the data
#
# 1. Read the Analytics API access policy, including the User-Agent requirement.
# 2. Choose one article title encoded for the URL path.
# 3. Request a bounded daily pageview series and keep requests serial.

# %% [markdown]
# ## Install packages
#
# Run this cell first.

# %%
# python -m pip install pandas requests
python -m pip install pandas requests

# %% [markdown]
# ## Python example

# %%
import pandas as pd
import requests

response = requests.get(
    "https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/"
    "en.wikipedia/all-access/user/Earth/daily/20250801/20250807",
    headers={
        "User-Agent": (
            "TrilemmaDataCatalogExample/1.0 "
            "(https://data.trilemma.foundation)"
        )
    },
    timeout=30,
)
response.raise_for_status()
pageviews = pd.DataFrame(response.json()["items"])
pageviews["retrieved_at_utc"] = pd.Timestamp.now(tz="UTC")
print(pageviews[["timestamp", "views"]])

# %% [markdown]
# ## First project: Chart one Wikipedia article's daily pageviews
#
# Describe how views of one article moved across a seven-day window.
#
# 1. Confirm the response includes daily view counts for the selected article and dates.
# 2. Plot views over time and note spikes that may reflect news coverage rather than lasting interest.
# 3. State that pageviews are not a measure of article quality, public opinion, or product demand.
