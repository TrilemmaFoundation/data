# %% [markdown]
# # UK Police Street-Level Crime
#
# Monthly street-level crime and outcome records for building neighbourhood safety monitors in England, Wales, and Northern Ireland.
#
# - Guide: https://data.trilemma.foundation/datasets/uk-police-street-crime
# - Official source: https://data.police.uk/
# - Data terms: https://data.police.uk/about/
# - Last verified: 2026-08-18

# %% [markdown]
# ## Overview
#
# The Police API returns street-level crimes for a point or custom area. Start with one coordinate pair and the most recently published month. Locations are snapped to anonymised map points, reporting coverage varies by force, and counts are not official statistics.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the Data
#
# 1. Read the data.police.uk about page and the Open Government Licence notice.
# 2. Request street-level crimes for one latitude and longitude.
# 3. Keep category, month, and the anonymised street name.

# %% [markdown]
# ## Install Packages
#
# Run this cell first.

# %%
# %pip install pandas requests
# %pip install pandas requests

# %% [markdown]
# ## Python Example

# %%
import pandas as pd
import requests

response = requests.get(
    "https://data.police.uk/api/crimes-street/all-crime",
    params={"lat": 51.5074, "lng": -0.1278},
    timeout=30,
)
response.raise_for_status()
crimes = pd.json_normalize(response.json())
print(crimes[["id", "category", "month", "location.street.name"]].head(20))
print(crimes["category"].value_counts().head())

# %% [markdown]
# ## First Project: Summarise Recent Street Crime around One Point
#
# Test whether category counts can power a neighbourhood safety snapshot.
#
# 1. Keep crime id, category, month, and anonymised street name.
# 2. Count records by category and flag missing coordinates.
# 3. Explain that points are snapped for privacy and that force coverage and lag limit comparison across areas.
