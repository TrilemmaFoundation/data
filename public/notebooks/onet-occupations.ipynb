# %% [markdown]
# # O*NET Occupational Database
#
# U.S. occupation titles, skills, and task descriptions for building job-profile and labor-market research tools from published database files.
#
# - Guide: https://data.trilemma.foundation/datasets/onet-occupations
# - Official source: https://www.onetcenter.org/database.html
# - Data terms: https://www.onetcenter.org/license_db.html
# - Last verified: 2026-08-18

# %% [markdown]
# ## Overview
#
# O*NET publishes occupation codes, titles, and descriptions as downloadable database files under CC BY 4.0. Start with the Occupation Data CSV, not the paid-product Web Services free-tier. Titles are a taxonomy, not a vacancy count, and O*NET is a trademark of USDOL/ETA.

# %% [markdown]
# ## Prerequisites
#
# - Python 3.10 or newer
# - A notebook environment such as Jupyter or Google Colab
# - An internet connection

# %% [markdown]
# ## Access the Data
#
# 1. Open the database page and read the CC BY attribution requirements.
# 2. Download the published Occupation Data file, not services.onetcenter.org.
# 3. Keep O*NET-SOC codes as text and credit O*NET 30.3 Database.

# %% [markdown]
# ## Install Packages
#
# Run this cell first.

# %%
# %pip install pandas
# %pip install pandas

# %% [markdown]
# ## Python Example

# %%
import pandas as pd

occupations = pd.read_csv(
    "https://www.onetcenter.org/dl_files/database/db_30_3_text/Occupation%20Data.txt",
    sep="\t",
)
print(occupations.head())
print(occupations.columns.tolist())

# %% [markdown]
# ## First Project: Browse Published O*NET Occupation Titles
#
# Test whether the Occupation Data file can power a bounded job-profile lookup.
#
# 1. Keep O*NET-SOC code, title, and description as published.
# 2. Search for one occupation family by title keywords and count matching codes.
# 3. Attribute O*NET 30.3 Database under CC BY 4.0 and explain that titles are not a measure of hiring demand.
